# %% [markdown]
# # Assignment 1

# %% [markdown]
# Please submit your assignment as an HTML or PDF file.

# %% [markdown]
# Type your name in the code cell below (you can either store it in a variable or use `print(...)`).

# %%
# Write your code here

# %% [markdown]
# (a) Import the `pandas`, `numpy`, and `matplotlib` packages

# %%
# Write your code here

# %% [markdown]
# (b) Open the dataset `worldbank_wdi_2019.csv` in the same folder as this notebook
#
# - Read it as a pandas object called `wdi`
# - Note: This is a subset of the World Development Indicators for 2019

# %%
# Write your code here

# %% [markdown]
# (c) View the dataset and create a list of variable names

# %%
# Create a list, e.g. "variable_names = [ "name1", "name2", "name3" ]"
# Manually type the names of the 4 variables
# If you're viewing the dataset from the VS-Code "Variables" tool, you'll
# see an extra column "index". Do not include this in your list.

# %% [markdown]
# (d) Compute descriptive statistics for the fourth variable in the dataset
#
# - One way to do this is: `wdi["gdp_per_capita_usd"].describe()`
# - Do something similar, but with the list you created above.
# - Substitute `gdp_per_capita_usd` with a command that extracts the fourth element in the list: `wdi[your_list[3]].describe()`
# - The output should match `wdi["gdp_per_capita_usd"].describe()`, since that is the fourth column. If it does not, double-check the order of the names in your list.

# %%
# Remember that the numbering in Python starts at zero
# For example:
# list_colors = ["red","green","yellow"]
# list_colors[2] will output "yellow"

# %% [markdown]
# (e) Show a scatter plot that shows `gdp_per_capita_usd` in the x-axis and `life_expectancy` in the y-axis.
#
# - Label the axes for full points
# - Note: This question does not depend on (d)

# %%
# Write your code here

# %% [markdown]
# (f) Boolean logic with arrays
#
# - Convert the `gdp_per_capita_usd` column into a NumPy array (e.g. `gdp_array = np.array(wdi["gdp_per_capita_usd"])`)
# - Create a boolean array that is `True` whenever a country has a `gdp_per_capita_usd` greater than 10,000, and `False` otherwise
# - Use `np.sum()` on the boolean array to count how many countries meet this condition (`True` counts as 1, `False` as 0)
# - Print the count

# %%
# Hint: start by converting wdi["gdp_per_capita_usd"] to a NumPy array with np.array(...)
# Then build a boolean array with the comparison > 10000
# Finally use np.sum() to count how many True values it contains

# %% [markdown]
# (g) Combining two boolean conditions
#
# In Lecture 03 you saw that boolean arrays can be combined element-by-element with `&` ("and") and `|` ("or"). For example, `(ages >= 20) & (ages <= 30)` returns `True` only for the elements where **both** conditions hold.
#
# - Convert the `life_expectancy` column to a NumPy array (e.g. `life_array = np.array(wdi["life_expectancy"])`).
# - Build a boolean array that is `True` only for countries where **both** `gdp_per_capita_usd > 10000` **and** `life_expectancy > 70`. Combine the two conditions with `&` and remember to wrap each comparison in parentheses.
# - Use `np.sum()` on the combined boolean array to count how many countries satisfy both conditions.
# - Print the count.
#
# Hint: the structure looks like `(array_a > value1) & (array_b > value2)`.

# %%
# Write your code here
