# %% [markdown]
# # Assignment 4

# %% [markdown]
# Please submit your assignment as an HTML or PDF file.

# %% [markdown]
# Type your name and Emory ID in the code cell below.

# %%
# Write your answer here:

# %% [markdown]
# Import the `pandas`, `matplotlib.pyplot`, `numpy`, and `sqlite3` libraries.

# %%
# Write your answer here:

# %% [markdown]
# (a) Boolean filtering with `[]`
#
# - Read the dataset labelled `data/features.csv`.
# - Use the `[]` operator with a boolean condition to select all rows where `mpg > 25`. Store the result in a new DataFrame called `efficient_cars`.
# - Print `len(efficient_cars)` to show how many cars satisfy the condition.
# - For comparison, also select cars where `weight < 2500` and `cylinders == 4` at the same time (combining two conditions with `&`).
#
# Hint: `carfeatures[carfeatures['mpg'] >= 25]` from Lecture 10 shows the pattern.

# %%
# Write your answer here

# %% [markdown]
# (b) Subsetting with `.query()` and a global variable
#
# - Read the dataset labelled `data/features.csv`.
# - Define a variable called `threshold` and assign it the value 3000.
# - Use `.query()` to create two subsets: one where `weight > threshold` and one where `weight <= threshold`. Reference the variable with the `@` prefix inside the query string (`@threshold`).
# - Compute the mean `acceleration` for each subset.

# %%
# Write your answer here:

# %% [markdown]
# (c) Sorting and `.iloc[]`
#
# - Read the `data/fifa23_players_basic.csv` dataset.
# - Use `.sort_values()` to order the rows by `Age` from youngest to oldest.
# - Use `.iloc[]` to extract the first 5 rows of the sorted DataFrame (the 5 youngest players). Display the result.

# %%
# Write your own code

# %% [markdown]
# (d) `.query()` with column names that contain spaces
#
# - Read the `data/fifa23_players_basic.csv` dataset.
# - Compute the mean of the column `Value(in Euro)` and store it as a variable called `mean_value`.
# - Use `.query()` to subset the players whose value is above the mean.
#
# Hint: when a column name contains spaces or punctuation, wrap it in backticks inside the query string, e.g. `` `Value(in Euro)` > @mean_value ``.

# %%
# Write your own code

# %% [markdown]
# (e) SQL via `sqlite3` in Python
#
# The `fifa23_players_basic.csv` dataset can also be queried with SQL. Write Python code that does the following:
#
# 1. Connect to a SQLite database called `fifa.db` using `sqlite3.connect()`.
# 2. Load `data/fifa23_players_basic.csv` into a pandas DataFrame.
# 3. Write the DataFrame to a SQL table called `players` using `.to_sql()` with `if_exists="replace"` and `index=False`.
# 4. Use `pd.read_sql()` to run a `SELECT` query that returns the `"Known As"`, `"Nationality"`, and `"Overall"` columns for the top 5 players by `"Overall"` rating, sorted from highest to lowest. Display the result.
#
# Hint: when a SQL column name contains spaces, wrap it in double quotes inside the query string, e.g. `SELECT "Known As" FROM players`.

# %%
# Write your own code

# %% [markdown]
# (f) SQL aggregation: `GROUP BY` and `HAVING`
#
# Using the same `players` table, write a SQL query with `pd.read_sql()` that:
#
# 1. Computes the average `Overall` rating per `Nationality`.
# 2. Keeps only nationalities with more than 100 players (using `HAVING COUNT(*) > 100`).
# 3. Orders the results from highest average rating to lowest.
#
# Display the result.

# %%
# Write your own code
