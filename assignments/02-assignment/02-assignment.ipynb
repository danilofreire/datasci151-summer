# %% [markdown]
# # Assignment 2

# %% [markdown]
# Please submit your assignment as an HTML or PDF file.

# %% [markdown]
# Type your name and Emory ID in the code cell below.

# %%
# Write your code here

# %% [markdown]
# Import the `numpy` and `matplotlib` packages

# %%
# Write your own code

# %% [markdown]
# (a) Compute a formula:
#
# $V=P\left(1+{\frac {r}{n}}\right)^{nt}$
#
# Calculate $V$ when:
# - $P = 1800$
# - $r = 0.24$
# - $n = 12$
# - $t = 8$
#
# To get full points:
# - First define each of these variables
# - Write the formula above

# %%
# Note (if you're interested in the context)
# V = Accumulated value of investment
# P = Principal (the amount initially deposited)
# r = Annual interest rate (as a decimal, so 0.24 = 24% per year)
# n = Number of compounding periods per year (n = 12 means monthly compounding)
# t = Number of years

# Write your own code

# %% [markdown]
# (b) Composite operations on arrays
#
# - Define $r = 0.06$.
# - Define two arrays $a$ and $t$ using `np.array()`, with the following values <br>
#
# $ a = \begin{pmatrix} a_0 \\ a_1 \\ a_2 \end{pmatrix} = \begin{pmatrix} 20 \\ 30 \\ 15 \end{pmatrix}, \qquad t = \begin{pmatrix} t_0 \\ t_1 \\ t_2 \end{pmatrix} = \begin{pmatrix} 0 \\ 1 \\ 2 \end{pmatrix} $
#
# (the subscripts $a_0, a_1, a_2$ refer to the individual elements of $a$).
#
# - Use element-by-element vector operations to compute a new array $M$ of length 3: <br>
#
# $ M = \begin{pmatrix} a_0 / (1+r)^{t_0} \\ a_1 / (1+r)^{t_1} \\ a_2 / (1+r)^{t_2} \end{pmatrix} $
#
# - Compute the sum of the values of $M$ using `M.sum()`.
# - To get full points you must do all of the above tasks.
#
# Context: this is a present-value calculation. Each $a_i$ is a future cash flow received after $t_i$ years, and $r$ is the discount rate. Summing $M$ gives the total present value.

# %%
# Write your own code

# %% [markdown]
# (c) Plot a normal random variable
#
# To get full points:
#
# - Set a seed using `np.random.seed()` (any integer is fine).
# - Create the random variable using `np.random.normal(loc=3.5, scale=1.5, size=1500)` (i.e. mean = 3.5, standard deviation = 1.5, 1500 draws).
# - Plot a histogram of the values with `plt.hist()`.
# - Label both axes.
# - After the plot, add a one-sentence comment (using `#`) describing the shape of the histogram. Where is it centred? Is it symmetric? Does its shape match what you would expect from a normal distribution?

# %%
# Write your own code

# %% [markdown]
# (d) Checking whether a word is part of a list
#
# - Define a variable `animal` with the value `"dog"`.
# - Define a list of animals: `list_animals = ["cat", "rabbit", "dog"]`.
# - Write an expression to test whether `animal` is contained in `list_animals` and store the result in a variable `result`.
#
# Hint: use the `in` operator. The result should be `True` or `False`.

# %%
# Write your own code

# %% [markdown]
# (e) Classifying a variable
#
# - Define a new variable `temperature` and assign it the value `25`.
# - Write an `if/elif/else` statement that does the following:
#     - Prints `Temperature below 15` if the temperature is less than or equal to 15.
#     - Prints `Temperature between 15 and 20` if the temperature is strictly greater than 15 and less than or equal to 20.
#     - Prints `Temperature above 20` if the temperature is strictly higher than 20.
#
# To get full points you must follow all of the above instructions.

# %%
# Write your own code

# %% [markdown]
# (f) Looping with conditionals
#
# Use a `for` loop to iterate over the list `temperatures = [10, 14, 17, 22, 25, 30]`. For each value, print a message that classifies the temperature using the same rule as in (e):
#
# - Print `Temperature below 15` if the value is less than or equal to 15
# - Print `Temperature between 15 and 20` if the value is strictly greater than 15 and less than or equal to 20
# - Print `Temperature above 20` if the value is strictly higher than 20
#
# To get full points your loop must print exactly six lines, one per value in the list.

# %%
# Write your own code

# %% [markdown]
# (g) Writing your own function
#
# Define a function `fn_compound_interest(P, r, n, t)` that takes the four arguments from (a) and returns $V$ using the same formula.
#
# - Use the `def` keyword and a `return` statement
# - After defining the function, call it with the values from (a): `P = 1800`, `r = 0.24`, `n = 12`, `t = 8`
# - Print the result and check that it matches the value you computed in (a)
#
# To get full points you must define the function and call it at least once.

# %%
# Write your own code
