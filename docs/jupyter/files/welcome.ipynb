# %% [markdown]
# # Welcome to DATASCI 151! 🐍
#
# This is JupyterLite, a Python environment that runs entirely in your
# browser. No installation required. Everything you write here stays on
# your machine until you save it.
#
# **A few things to know:**
#
# - The first cell that imports pandas/numpy can take 10 to 20 seconds
#   while Pyodide loads. After that, things are fast.
# - Files you create here are saved in your browser's storage. Download
#   them to your computer if you want to keep them long-term.
# - This is a sandbox for experimenting. For graded work, use the local
#   Anaconda + VSCode setup from Tutorial 01.

# %%
print("Hello, DATASCI 151!")
2 + 2

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "name":  ["Ada", "Linus", "Grace", "Tim"],
    "field": ["maths", "kernel", "compilers", "web"],
    "year":  [1843, 1991, 1959, 1989],
})
df

# %%
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.title("sin(x)")
plt.show()
